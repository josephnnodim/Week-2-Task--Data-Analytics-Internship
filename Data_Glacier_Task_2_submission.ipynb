# %%
#Data Glacier- Data Analytics internship week 2 task

#Data Analysis Internship-Week 2 Task

# %%
#Reference sources that have been used for this task include:
#https://www.youtube.com/watch?v=ht5buXUMqkQ
#https://www.python.org/
#https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html

#Python Pandas Tutorial (Part 8): Grouping and Aggregating - Analyzing and Exploring Your Data
#https://www.youtube.com/watch?v=txMdrV1Ut64

# %%
#In this task, we are going to use the Pandas library because it is a useful tool that enables us to read various datasets
#into a data frame

# %%
# Let's import the needed libraries
import pandas as pd                       #A library for reading data into dataframes
import numpy as np                        #An indexing and mathematical computing library
import matplotlib as plt                 #Alibrary for visualising data

# %%
#Let's read the files.
#The files have been uploaded into Jupiter. As they are Excel files in csv format, we would use the .csv extension

#Lets start with the Transactions_data.
Transaction_data = pd.read_csv('Data_Glacier_Transaction_ID.csv')
print(Transaction_data)
print("\n")
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011            1         Card
# 1             10000012            1         Card
# 2             10000013            1         Cash
# 3             10000014            1         Cash
# 4             10000015            1         Card
# ...                ...          ...          ...
# 440093        10440104        60000         Cash
# 440094        10440105        60000         Cash
# 440095        10440106        60000         Card
# 440096        10440107        60000         Card
# 440097        10440108        60000         Card
#
# [440098 rows x 3 columns]

# %%
#This can also be shown as 
print(Transaction_data.shape)
# Out:
# (440098, 3)

# %%
#We can see that the table has 440098 rows and 3 features. 
#Note that the first column displayed is just the seriel numbers for the rows and is not included in the data, so does
#not count as one of the features.

#The information is flled in the data intake form

# %%
#Lets read in the Cab data
Cab_data = pd.read_csv('Data_Glacier_Cab_Data.csv')
Cab_data
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
# 359391         12.76         191.58      177.6192
#
# [359392 rows x 7 columns]

# %%
#We can see that the table has 359,392 rows and 7 features. 
#Note that the first column displayed is just the seriel numbers for the rows and is not included in the data, so does
#not count as one of the features.

# %%
#Lets read in the City data
City_data = pd.read_csv('Data_Glacier_City.csv')
City_data
# Out:
#                 City Population    Users
# 0        NEW YORK NY  8,405,837  302,149
# 1         CHICAGO IL  1,955,130  164,468
# 2     LOS ANGELES CA  1,595,037  144,132
# 3           MIAMI FL  1,339,155   17,675
# 4     SILICON VALLEY  1,177,609   27,247
# 5      ORANGE COUNTY  1,030,185   12,994
# 6       SAN DIEGO CA    959,307   69,995
# 7         PHOENIX AZ    943,999    6,133
# 8          DALLAS TX    942,908   22,157
# 9         ATLANTA GA    814,885   24,701
# 10         DENVER CO    754,233   12,421
# 11         AUSTIN TX    698,371   14,978
# 12        SEATTLE WA    671,238   25,063
# 13         TUCSON AZ    631,442    5,712
# 14  SAN FRANCISCO CA    629,591  213,609
# 15     SACRAMENTO CA    545,776    7,044
# 16     PITTSBURGH PA    542,085    3,643
# 17     WASHINGTON DC    418,859  127,001
# 18      NASHVILLE TN    327,225    9,270
# 19         BOSTON MA    248,968   80,021

# %%
#We can see that the table has 19 rows and 3 features. 
#Note that the first column displayed is just the seriel numbers for the rows and is not included in the data, so does
#not count as one of the features.

# %%
#Lets read in the Customer_ID data
Customerid_data = pd.read_csv('Data_Glacier_Customer_ID.csv')
Customerid_data
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0                1    Male   36               16359
# 1                2    Male   31               12069
# 2                3  Female   27               12968
# 3                4    Male   33               13803
# 4                5    Male   24                9965
# ...            ...     ...  ...                 ...
# 49166        59996    Male   51               16634
# 49167        59997    Male   63               22352
# 49168        59998  Female   23                5678
# 49169        59999    Male   38               24577
# 49170        60000  Female   27               20303
#
# [49171 rows x 4 columns]

# %%
#We can see that the table has 49171 rows and 4 features. 
#Note that the first column displayed is just the seriel numbers for the rows and is not included in the data, so does
#not count as one of the features.

# %%
#To ensure that that the data is in the suitable for analysis, we would do some data exploration and cleaning
#Let's start by checking for missing values

#Let's start with the transaction data

# %%
#Lets check the data types for each of the columns in each table


print("For the Transaction data table")
print(Transaction_data.dtypes)
print("\n")

print("For the Customer ID data table")
print(Customerid_data.dtypes)
print("\n")

print("For the City data table")
print(City_data.dtypes)
print("\n")

print("For the Cab_data table")
print(Cab_data.dtypes)
# Out:
# For the Transaction data table
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object
#
#
# For the Customer ID data table
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object
#
#
# For the City data table
# City          object
# Population    object
# Users         object
# dtype: object
#
#
# For the Cab_data table
# Transaction ID      int64
# Date of Travel      int64
# Company            object
# City               object
# KM Travelled      float64
# Price Charged     float64
# Cost of Trip      float64
# dtype: object

# %%
#We can see that:

#the Transaction table has two integer data type columns and one column with mixed data type

#the Transaction data has two integer data type columns and one column with mixed data type

#all the columns in the City table have mixed data type

#the Cab data table contains two columns with integer data type, two columns with mixed data type and three two columns with 
#decimal numbers data type.

# %%
#Before we proceed, let's ensure that there are thesame number of customer IDs in all the table where they are occur.
#Customer ID occur in both the Transaction data table and the customer id table, so lets check

print("Ensuring equal number of data for primary keys in tables")
print("\n")

print(Transaction_data.nunique())

print("\n")
print(Customerid_data.nunique())
# Out:
# Ensuring equal number of data for primary keys in tables
#
#
# Transaction ID    440098
# Customer ID        49171
# Payment_Mode           2
# dtype: int64
#
#
# Customer ID           49171
# Gender                    2
# Age                      48
# Income (USD/Month)    23341
# dtype: int64

# %%
#Good! We can see that there are exactly thesame number of customer ID values (which is 49171) in both tables.

# %%
#Let's check for missing values
print('The number of missing values in each column of the Transaction table are: ')
print(Transaction_data.isnull().sum())

print("\n")

print('The number of missing values in each column of the Customer ID table are: ')
print(Customerid_data.isnull().sum())

print("\n")

print('The number of missing values in each column of the Cab table are: ')
print(Cab_data.isnull().sum())

print("\n")

print('The number of missing values in each column of the City_data table are: ')
City_data.isnull().sum()
# Out:
# The number of missing values in each column of the Transaction table are:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64
#
#
# The number of missing values in each column of the Customer ID table are:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64
#
#
# The number of missing values in each column of the Cab table are:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64
#
#
# The number of missing values in each column of the City_data table are:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
#Wao! There are no missing values in any of the table and this is desirable as it will reduce the time for cleaning

# %%
#Let's check for missing values

print("Checking for missing values")
print("\n")

print('The number of missing values in each column of the Transaction table are: ')
print(Transaction_data.isnull().sum())

print("---------------------------------------------------------------------------")

print('The number of missing values in each column of the Customer ID table are: ')
print(Customerid_data.isnull().sum())

print("---------------------------------------------------------------------------")


print('The number of missing values in each column of the Cab table are: ')
print(Cab_data.isnull().sum())

print("---------------------------------------------------------------------------")


print('The number of missing values in each column of the City_data table are: ')
City_data.isnull().sum()
# Out:
# Checking for missing values
#
#
# The number of missing values in each column of the Transaction table are:
# Transaction ID    0
# Customer ID       0
# Payment_Mode      0
# dtype: int64
# ---------------------------------------------------------------------------
# The number of missing values in each column of the Customer ID table are:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64
# ---------------------------------------------------------------------------
# The number of missing values in each column of the Cab table are:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64
# ---------------------------------------------------------------------------
# The number of missing values in each column of the City_data table are:
# City          0
# Population    0
# Users         0
# dtype: int64

# %%
##Let's check for duplicated values in the Transaction data tables


Transaction_data.duplicated()

#Let's check for duplicated values, starting from the transaction table
Transaction_data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 440093    False
# 440094    False
# 440095    False
# 440096    False
# 440097    False
# Length: 440098, dtype: bool

# %%
#We seam to to be getting 'False' result for all the records so there are probably no duplicate row.
#To be sure there are no duplicate rows, lets count/sum (use .sum) the number of duplicate rows in the tables

# %%
#Lets check for duplicates along the rows for each table

print("Transaction_data table")
print(Transaction_data.index.duplicated())

print("\n")
print("Cab_data table")
print(Cab_data.index.duplicated())

print("\n")
print("Customer ID table")
print(Customerid_data.index.duplicated())

print("\n")
print("City table")
print(City_data.index.duplicated())
# Out:
# Transaction_data table
# [False False False ... False False False]
#
#
# Cab_data table
# [False False False ... False False False]
#
#
# Customer ID table
# [False False False ... False False False]
#
#
# City table
# [False False False False False False False False False False False False
#  False False False False False False False False]

# %%
#Confirming absence of duplicate rows in the tables

print("CHECKING FOR DUPLICATE ROWS")
print("\n")

print("There are", Transaction_data.duplicated().sum(), "duplicates rows in the Transaction data table")      

print('There are', City_data.duplicated().sum(), "duplicates row in the City_data table")

print("There are", Customerid_data.duplicated().sum(), "duplicates rows in the Customer_id table")

print("There are", Cab_data.duplicated().sum(), "duplicates rows in the Cab_data table")
# Out:
# CHECKING FOR DUPLICATE ROWS
#
#
# There are 0 duplicates rows in the Transaction data table
# There are 0 duplicates row in the City_data table
# There are 0 duplicates rows in the Customer_id table
# There are 0 duplicates rows in the Cab_data table

# %%
#Great! there are no duplicate rows.

# %%
#Let's check if there are outliers in the "KM Travelled" column of the Cab_dataset.
#One way to check for outliers is to arrange the data in rank, then observe if there is any extreme value. But this
#is impractical for huge datasets. 

#Lets arrange in rank order
sorted(Cab_data["KM Travelled"])
# Out:
# [1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.9,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.92,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  1.94,
#  ...]

# %%
#We would detect outliers in the Cab_data table using Interquartile range
#Any number less than the lower bounds or greater than the upper bounds is considered to be 
#an outlier, where
print("CHECKING FOR OUTLIERS")
print("\n")
print("Checking for outliers in the 'KM Travelled' column")
print("\n")

#We will do this in a few steps

#Step 1
print("step 1: Calculating the first and third quartile")

#Lets extract the column of interest from the Cab_data table

distance=Cab_data['KM Travelled']
distance

first_quartile, third_quartile= np.percentile(distance,[25,75])
print(first_quartile, third_quartile)

#Step 1
print("\n")
#Step 2
print("step 2: Calculating the Interquartile range")
IQR=third_quartile-first_quartile
print(IQR)


#Step 3
#Lets get the lower bound and upper bound using the
print("\n")
print("step 3: Calculating the lower and upper bounds")

lower_bound = first_quartile-(1.5 * IQR) 
upper_bound = third_quartile +(1.5 * IQR)

print("Lower bound")
print(lower_bound)
print("\n")
print("Upper bound")
print(upper_bound)
print("\n")

#Lets get the quartiles
#Let's get the interquartile range



#Step 4:
#Any number outside the range (-19.44 to 64.4) will be considered an outlier
print("Any number outside the range (-19.44 to 64.4) will be considered an outlier. Lets see the minimum and maximum values")
#We would check the minimum and maximum values to see if they fall within the range

print("\n")
print("Step 4: Minimum and maximum values")

print("Minimum distance")
print(min(distance))
print("\n")
print("Maximum distance")
print(max(distance))
# Out:
# CHECKING FOR OUTLIERS
#
#
# Checking for outliers in the 'KM Travelled' column
#
#
# step 1: Calculating the first and third quartile
# 12.0 32.96
#
#
# step 2: Calculating the Interquartile range
# 20.96
#
#
# step 3: Calculating the lower and upper bounds
# Lower bound
# -19.44
#
#
# Upper bound
# 64.4
#
#
# Any number outside the range (-19.44 to 64.4) will be considered an outlier. Lets see the minimum and maximum values
#
#
# Step 4: Minimum and maximum values
# Minimum distance
# 1.9
#
#
# Maximum distance
# 48.0

# %%
#Since the minimum and maximum distance fall within the range (-19.44 to 64.4), there is no outlier in the "KM Travelled" column

# %%
#A better visualisation of the distribution to detect outliers is the boxplot
plt.boxplot(distance)
plt.title("Boxplot check for Outliers in KM Travelled Column of the Cab_data table")
plt.ylabel("KM Travelled")
# Out:
# Text(0, 0.5, 'KM Travelled')

# %%
#Similarly, the check for outliers for the 'Price Charged' is shown below

print("CHECKING FOR OUTLIERS FOR THE 'PRICE CHARGE' TABLE")
print("\n")
print("Checking for outliers in the 'Price Charged' column")
print("\n")

#Step 1
print("step 1: Calculating the first and third quartile")

#Lets extract the column of interest from the Cab_data table

Price=Cab_data['Price Charged']
Price

first_quartile, third_quartile= np.percentile(distance,[25,75])
print(first_quartile, third_quartile)

#Step 1
print("\n")
#Step 2
print("step 2: Calculating the Interquartile range")
IQR=third_quartile-first_quartile
print(IQR)


#Step 3
#Lets get the lower bound and upper bound using the
print("\n")
print("step 3: Calculating the lower and upper bounds")

lower_bound = first_quartile-(1.5 * IQR) 
upper_bound = third_quartile +(1.5 * IQR)

print("Lower bound")
print(lower_bound)
print("\n")
print("Upper bound")
print(upper_bound)
print("\n")

#Lets get the quartiles
#Let's get the interquartile range



#Step 4:
#Any number outside the range (-19.44 to 64.4) will be considered an outlier
print("Any number outside the range (-359.4 to 1149.5) will be considered an outlier. Lets see the minimum and maximum values")
#We would check the minimum and maximum values to see if they fall within the range

print("\n")
print("Step 4: Minimum and maximum values")

print("Minimum Price")
print(min(Price))
print("\n")
print("Maximum Price")
print(max(Price))
# Out:
# CHECKING FOR OUTLIERS FOR THE 'PRICE CHARGE' TABLE
#
#
# Checking for outliers in the 'Price Charged' column
#
#
# step 1: Calculating the first and third quartile
# 12.0 32.96
#
#
# step 2: Calculating the Interquartile range
# 20.96
#
#
# step 3: Calculating the lower and upper bounds
# Lower bound
# -19.44
#
#
# Upper bound
# 64.4
#
#
# Any number outside the range (-359.4 to 1149.5) will be considered an outlier. Lets see the minimum and maximum values
#
#
# Step 4: Minimum and maximum values
# Minimum Price
# 15.6
#
#
# Maximum Price
# 2048.03

# %%
# We can see that the minimum value (15.6) fall within the range (-359.4 to 1149.5), but the maximum value (2048.03) 
#fall outside the range, so is considered an outlier.

# %%
#Lets visualise this result by checking the skewness

# %%
#A better visualisation of the distribution to detect outliers is the boxplot
plt.boxplot(Price)
plt.title("Boxplot check for Outliers in 'Price Charged' Column of the Cab_data table")
plt.ylabel("Price Charged")
plt.xlabel("Price 'Charged' Column")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [196], in <cell line: 5>()
#       3 plt.title("Boxplot check for Outliers in 'Price Charged' Column of the Cab_data table")
#       4 plt.ylabel("Price Charged")
# ----> 5 plt.xlabel("Price 'Charged' Column")
#
# TypeError: 'str' object is not callable

# %%
#let's check if any of the features in the tables have duplicate value, starting from the Traansaction table.

print("Checking individual columns for duplicate")

print("\n")
print('For the Transaction table,')
print("There are", Transaction_data['Transaction ID'].duplicated().sum(), "duplicates in the Transaction ID Column")      
print('There are', Transaction_data['Customer ID'].duplicated().sum(), "duplicates in the Customer ID Column")
print("There are", Transaction_data['Payment_Mode'].duplicated().sum(), "duplicates in the Payment_Mode Column")

print("\n")

print('For the Cab data Table,')
print("There are", Cab_data['Transaction ID'].duplicated().sum(), "duplicates in the 'Transaction ID' Column")      
print('There are', Cab_data['Date of Travel'].duplicated().sum(), "duplicates in the 'Date of Travel' Column")
print("There are", Cab_data['Company'].duplicated().sum(), "duplicates in the 'Company' Column")
print("There are", Cab_data['City'].duplicated().sum(), "duplicates in the 'City' Column")
print("There are", Cab_data['KM Travelled'].duplicated().sum(), "duplicates in the 'KM Travelled'Column")
print("There are", Cab_data['Price Charged'].duplicated().sum(), "duplicates in the 'Price Charged' Column")
print("There are", Cab_data['Cost of Trip'].duplicated().sum(), "duplicates in the 'Cost of Trip' Column")


print("\n")
print('For the City table')
print("There are", City_data['City'].duplicated().sum(), "duplicates in the 'City' Column")      
print('There are', City_data['Population'].duplicated().sum(), "duplicates in the 'Population' Column")
print("There are", City_data['Users'].duplicated().sum(), "duplicates in the 'Users' Column")

print("\n")
print('For the Customer ID Table,')
print("There are", Customerid_data['Customer ID'].duplicated().sum(), "duplicates in the 'Customer ID' Column")
print("There are", Customerid_data['Gender'].duplicated().sum(), "duplicates in the 'Gender'Column")
print("There are", Customerid_data['Age'].duplicated().sum(), "duplicates in the 'Age' Column")
print("There are", Customerid_data['Income (USD/Month)'].duplicated().sum(), "duplicates in the 'Income (USD/Month)' Column")
# Out:
# Checking individual columns for duplicate
#
#
# For the Transaction table,
# There are 0 duplicates in the Transaction ID Column
# There are 390927 duplicates in the Customer ID Column
# There are 440096 duplicates in the Payment_Mode Column
#
#
# For the Cab data Table,
# There are 0 duplicates in the 'Transaction ID' Column
# There are 358297 duplicates in the 'Date of Travel' Column
# There are 359390 duplicates in the 'Company' Column
# There are 359373 duplicates in the 'City' Column
# There are 358518 duplicates in the 'KM Travelled'Column
# There are 260216 duplicates in the 'Price Charged' Column
# There are 343101 duplicates in the 'Cost of Trip' Column
#
#
# For the City table
# There are 0 duplicates in the 'City' Column
# There are 0 duplicates in the 'Population' Column
# There are 0 duplicates in the 'Users' Column
#
#
# For the Customer ID Table,
# There are 0 duplicates in the 'Customer ID' Column
# There are 49169 duplicates in the 'Gender'Column
# There are 49123 duplicates in the 'Age' Column
# There are 25830 duplicates in the 'Income (USD/Month)' Column

# %%
#Let's see the duplicate values in the Citycolumn for the Cab_data table
print(Cab_data.City.duplicated())
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 359387     True
# 359388     True
# 359389     True
# 359390     True
# 359391     True
# Name: City, Length: 359392, dtype: bool

# %%
#Oh! we seam to be having huge number of duplicates in certain columns.
#We can see that almost all the values show as duplicate.

# %%
#Let's check the table as a whole 

print(Cab_data.loc[Cab_data.City.duplicated(keep='last'), :])
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359386        10440100           43107  Yellow Cab  WASHINGTON DC
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95      313.6350
# 1              28.62         358.52      334.8540
# 2               9.04         125.20       97.6320
# 3              33.17         377.40      351.6020
# 4               8.73         114.62       97.7760
# ...              ...            ...           ...
# 359386         28.71         452.19      351.4104
# 359387          4.80          69.24       63.3600
# 359388          8.40         113.75      106.8480
# 359389         27.75         437.07      349.6500
# 359390          8.80         146.19      114.0480
#
# [359373 rows x 7 columns]

# %%
#Clearly, each of the tables contain at least one column with duplicate values.

# %%
#FEATURE SELECTION

#let us extract the columns of interest; but before that, lets have a look at the data briefly,

# %%
#Again, lets look at the tables

print("\n")
print("For the Transaction,")
print(Transaction_data.head())
print("\n")

print("\n")
print("For the Cab_data,")
print(Cab_data.head())
print("\n")

print("For the City_data,")
print("\n")
print(City_data.head())
print("\n")

print("\n")
print("For the Customer ID data,")
print(Customerid_data.head())
# Out:
# For the Transaction,
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011            1         Card
# 1        10000012            1         Card
# 2        10000013            1         Cash
# 3        10000014            1         Cash
# 4        10000015            1         Card
#
#
#
#
# For the Cab_data,
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
#
#
# For the City_data,
#
#
#              City Population    Users
# 0     NEW YORK NY  8,405,837  302,149
# 1      CHICAGO IL  1,955,130  164,468
# 2  LOS ANGELES CA  1,595,037  144,132
# 3        MIAMI FL  1,339,155   17,675
# 4  SILICON VALLEY  1,177,609   27,247
#
#
#
#
# For the Customer ID data,
#    Customer ID  Gender  Age  Income (USD/Month)
# 0            1    Male   36               16359
# 1            2    Male   31               12069
# 2            3  Female   27               12968
# 3            4    Male   33               13803
# 4            5    Male   24                9965

# %%
#Lets compare the two companies based on patronage
Cab_data['Company'].value_counts()
# Out:
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64

# %%
#We can see that more customers prefer the yellow cabs

# %%
# To see the results as percentages rather than just counts, we pass the normalise arguments to the value count function
#and set it = True

Cab_data['Company'].value_counts(normalize=True)
# Out:
# Yellow Cab    0.764294
# Pink Cab      0.235706
# Name: Company, dtype: float64

# %%
#We can see that approximately 76% prefered the yellow cab while 24% prefered the pink cab

# %%
#We could also visualise the results
ax = Cab_data['Company'].value_counts().plot(kind='bar', figsize=(10, 4), fontsize=13, color='brown')
ax.set_title('Graphical Distribution of cab preference', size=15, pad=15)
ax.set_ylabel('Number of boardings', fontsize=10)
ax.set_xlabel('Payment Method')

for i in ax.patches:
    ax.text(i.get_x() + 0.19, i.get_height() + 700, str(round(i.get_height(), 2)), fontsize=15)

# %%
#From the chart, we can see that customers appear to prefer the yello cab to the pink cab

# %%
#Lets have a look at the statistical summaries for each of the tables

# %%
print("STATISTICAL SUMMARY FOR THE DATA IN THE TABLES")


print("\n")
print("For the Customer ID data,")
print("\n")
print(Customerid_data.describe())
print("------------------------------------------------------------------------------------")
print("\n")

print("\n")
print("For the Transaction,")
print("\n")
print(Transaction_data.describe())
print("\n")
print("------------------------------------------------------------------------------------")
print("\n")

print("\n")
print("For the Cab_data,")
print("\n")
print(Cab_data.describe())
print("\n")
print("------------------------------------------------------------------------------------")
print("\n")

print("For the City_data,")
print("\n")
print(City_data.describe())
print("\n")
# Out:
# STATISTICAL SUMMARY FOR THE DATA IN THE TABLES
#
#
# For the Customer ID data,
#
#
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000
# ------------------------------------------------------------------------------------
#
#
#
#
# For the Transaction,
#
#
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000
#
#
# ------------------------------------------------------------------------------------
#
#
#
#
# For the Cab_data,
#
#
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000
#
#
# ------------------------------------------------------------------------------------
#
#
# For the City_data,
#
#
#                City Population    Users
# count            20         20       20
# unique           20         20       20
# top     NEW YORK NY  8,405,837  302,149
# freq              1          1        1

# %%
#Similarly, the check for outliers for the 'Price Charged' is shown below

print("CHECKING FOR OUTLIERS FOR THE 'PRICE CHARGE' TABLE")
print("\n")

print("Checking for outliers in the 'Price Charged' column")
print("------------------------------------------------------")

#Step 1
print("step 1: Calculating the first and third quartile")

#Lets extract the column of interest from the Cab_data table

Price=Cab_data['Price Charged']
Price

first_quartile, third_quartile= np.percentile(distance,[25,75])
print(first_quartile, third_quartile)

#Step 1
print("---------------------------------------------------------")
#Step 2
print("step 2: Calculating the Interquartile range")
IQR=third_quartile-first_quartile
print(IQR)


#Step 3
#Lets get the lower bound and upper bound using the
print("-------------------------------------------------------")
print("step 3: Calculating the lower and upper bounds")

lower_bound = first_quartile-(1.5 * IQR) 
upper_bound = third_quartile +(1.5 * IQR)

print("Lower bound")
print(lower_bound)
print("\n")
print("Upper bound")
print(upper_bound)
print("---------------------------------------------------------")

#Lets get the quartiles
#Let's get the interquartile range



#Step 4:
#Any number outside the range (-19.44 to 64.4) will be considered an outlier
print("Any number outside the range (-359.4 to 1149.5) will be considered an outlier. Lets see the minimum and maximum values")
#We would check the minimum and maximum values to see if they fall within the range

print("\n")
print("Step 4: Minimum and maximum values")

print("Minimum Price")
print(min(Price))
print("\n")
print("Maximum Price")
print(max(Price))
# Out:
# CHECKING FOR OUTLIERS FOR THE 'PRICE CHARGE' TABLE
#
#
# Checking for outliers in the 'Price Charged' column
# ------------------------------------------------------
# step 1: Calculating the first and third quartile
# 12.0 32.96
# ---------------------------------------------------------
# step 2: Calculating the Interquartile range
# 20.96
# -------------------------------------------------------
# step 3: Calculating the lower and upper bounds
# Lower bound
# -19.44
#
#
# Upper bound
# 64.4
# ---------------------------------------------------------
# Any number outside the range (-359.4 to 1149.5) will be considered an outlier. Lets see the minimum and maximum values
#
#
# Step 4: Minimum and maximum values
# Minimum Price
# 15.6
#
#
# Maximum Price
# 2048.03
